# %% [markdown]
# # Gradient Descent

# %% [markdown]
# ## Imports

# %%
# Import numpy
import numpy as np
# Import pyplot
import matplotlib.pyplot as plt
# jupyter notebook magic command
# %matplotlib inline

# %%
# Sets the plot style
plt.style.use(['ggplot'])

# %% [markdown]
# ## Create random data
#
# Generate random data with:
#
# $\theta_0=4$ - intercept
#
# $\theta_1=3$ - slope

# %%
# Create X values. np.random.rand creates an array of random values of shape (100, 1)
X = 2 * np.random.rand(100, 1)
# Function (f(x) = 4 + 3 * X) generates y-values and adds noise (chosen randomly from normal distribution)
y = 4 +3 * X+np.random.randn(100,1)

# %%
# Plot the data, color = blue, scatter ('b.')
plt.plot(X,y,'b.')
# Label the x-axis
plt.xlabel("$x$", fontsize=18)
# Label the y-axis
plt.ylabel("$y$", rotation=0, fontsize=18)
# Set axis ranges
_ =plt.axis([0,2,0,15])
# Out:
# [0, 2, 0, 15]

# %% [markdown]
# ## Analytical solution of Linear Regression

# %%
# Concanatge
X_b = np.c_[np.ones((100, 1)), X]
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print(theta_best)
# Out:
# [[3.85672877]
#  [3.08824954]]

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 3.85672877],
#        [10.03322786]])

# %% [markdown]
# <strong>Lets plot the prediction line with calculated theta</strong>

# %%
plt.plot(X_new, y_predict, 'r-')
plt.plot(X, y, 'b.')
plt.xlabel('$x_1$', fontsize=18)
plt.ylabel('$y$', fontsize=18)
plt.axis([0,2,0,15])
# Out:
# [0, 2, 0, 15]

# %% [markdown]
# # Gradient Descent Implementation
# ## Cost Function & Gradients

# %%
def print_results(theta, cost_history):
    print('Theta0: {:.3f}\nTheta1: {:.3f}\nFinal Cost (MSE): {:.3f}'.format(theta[0][0], theta[1][0], cost_history[-1]))

# %%
def calc_cost(theta, X, y):
    '''
    Calculates the cost for given X and y. The following shows
    an example of a single dimensional X.
    
    ----------
    Parameters:
    ----------
    
    theta = Vector of thetas
    X     = Row of X's: np.zeros((2, j))
    y     = Actual y's : np.zeros((2, 1))
    where j is the # of features
    '''
    
    m = len(y)
    
    predictions = X.dot(theta)
    
    cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

# %%
def gradient_descent(
    X,
    y,
    theta,
    learning_rate=0.01,
    iterations=100
):
    '''
    X    = Matrix of X with added bias units
    y    = Vector of Y
    theta=Vector of thetas np.random.randn(j,1)
    learning_rate 
    iterations = no of iterations
    
    Returns the final theta vector and array of cost history over no of iterations
    '''
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations, 2))
    for i in range(iterations):
        predictions = np.dot(X, theta)
        theta = theta - (1/m) * learning_rate * (X.T.dot((predictions - y)))
        theta_history[i, :] = theta.T
        cost_history[i] = calc_cost(theta, X, y)
    return theta, cost_history, theta_history

# %% [markdown]
# ## Lets start with 1000 iterations and a learning rate of 0.01 and a theta from a Gaussian (normal) distribution.

# %%
lr = 0.01
n_iter = 1000

theta = np.random.randn(2,1)

X_b = np.c_[np.ones((len(X), 1)), X]

theta, cost_history, theta_history = gradient_descent(
    X_b,
    y,
    theta,
    lr,
    n_iter
)
print('Theta0: {:.3f}\nTheta1: {:.3f}\nFinal Cost (MSE): {:.3f}'.format(theta[0][0], theta[1][0], cost_history[-1]))
# Out:
# Theta0: 3.630
# Theta1: 3.284
# Final Cost (MSE): 4983.816

# %%
fig, ax = plt.subplots(figsize=(12, 8))

ax.set_ylabel('J(theta)')
ax.set_xlabel('# of iterations')
ax.plot(range(n_iter), cost_history, 'b.')

# %% [markdown]
# <strong> After around 150 iterations the cost is flat so the remaining iterations  are not needed or will not result in any further optimization. Let us zoom in till iteration 200 and see the curve</strong>

# %%
fig, ax = plt.subplots(figsize=(12, 8))

ax.set_ylabel('J(theta)')
ax.set_xlabel('# of iterations')
ax.plot(range(200), cost_history[:200], 'b.')

# %% [markdown]
# ### It would be great to see the effect of different learning rates and iterations together

# %% [markdown]
# ### Let us  build a function which can show the effects together and also show how gradient decent actually is working

# %%
def plot_GD(n_iter,lr,ax,ax1=None):
     """
     n_iter = no of iterations
     lr = Learning Rate
     ax = Axis to plot the Gradient Descent
     ax1 = Axis to plot cost_history vs Iterations plot

     """
     _ = ax.plot(X,y,'b.')
     theta = np.random.randn(2,1)

     tr =0.1
     cost_history = np.zeros(n_iter)
     for i in range(n_iter):
        pred_prev = X_b.dot(theta)
        theta,h,_ = gradient_descent(X_b,y,theta,lr,1)
        pred = X_b.dot(theta)

        cost_history[i] = h[0]

        if ((i % 25 == 0) ):
            _ = ax.plot(X,pred,'r-',alpha=tr)
            if tr < 0.8:
                tr = tr+0.2
     if not ax1== None:
        _ = ax1.plot(range(n_iter),cost_history,'b.')

# %% [markdown]
# ### Plot the graphs for different iterations and learning rates combination

# %%
fig = plt.figure(figsize=(30,25),dpi=200)
fig.subplots_adjust(hspace=0.4, wspace=0.4)

it_lr =[(2000,0.001),(500,0.01),(200,0.05),(100,0.1)]
count =0
for n_iter, lr in it_lr:
    count += 1
    
    ax = fig.add_subplot(4, 2, count)
    count += 1
   
    ax1 = fig.add_subplot(4,2,count)
    
    ax.set_title("lr:{}".format(lr))
    ax1.set_title("Iterations:{}".format(n_iter))
    plot_GD(n_iter,lr,ax,ax1)

# %% [markdown]
# ### You can always plot Indiviual graphs to zoom in

# %%
_, ax = plt.subplots(figsize=(14,10))
plot_GD(100,0.1,ax)

# %% [markdown]
# # Stochastic Gradient Descent

# %%
def stochastic_gradient_descent(
    X,
    y,
    theta,
    learning_rate=.01,
    iterations=1000
):
    '''
    X = Matrix of X with added bias units
    y = Vector of Y
    theta = Vector of thetas np.random.randn(j, 1)
    
    Returns the final theta vector and of cost history over 
    no of iterations.
    '''
    
    m = len(y)
    cost_history = np.zeros(iterations)
    
    for it in range(iterations):
        cost = 0.0
        for i in range(m):
            rand_ind = np.random.randint(0, m)
            X_i = X[rand_ind, :].reshape(1, X.shape[1])
            y_i = y[rand_ind].reshape(1, 1)
            prediction = np.dot(X_i, theta)
            
            theta = theta - (1/m) * learning_rate * ( X_i.T.dot((prediction - y_i)))
            cost += calc_cost(theta, X_i, y_i)
        cost_history[it] = cost
    return theta, cost_history

# %%
lr = .5
n_iter = 50

theta = np.random.randn(2, 1)

X_b = np.c_[np.ones((len(X), 1)), X]
theta, cost_history = stochastic_gradient_descent(
    X_b,
    y,
    theta,
    lr,
    n_iter
)
# Out:
# Theta0: 3.852
# Theta1: 3.150
# Final Cost (MSE): 53.806

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.set_ylabel('$J(theta)$', fontsize=18)
ax.set_xlabel('$Iterations$', fontsize=18)

ax.plot(range(n_iter), cost_history, 'b.')

# %%
def minibatch_gradient_descent(
    X,
    y,
    theta,
    learning_rate=.01,
    iterations=100,
    batch_size=20,
):
    '''
    X = Matrix of X without added bias units
    y = Vector of Y
    theta = Vector of thetas np.random.randn(j, 1)
    iterations = no of iterations
    
    Returns the final theta vector and array of history over
    no of iterations.
    '''
    
    m = len(y)
    cost_history = np.zeros(iterations)
    n_batches = int(m/batch_size)
    
    for it in range(iterations):
        cost = 0.0
        indices = np.random.permutation(m)
        X = X[indices]
        y = y[indices]
        for i in range(0, m, batch_size):
            X_i = X[i:i+batch_size]
            y_i = y[i:i+batch_size]
            
            X_i = np.c_[np.ones(len(X_i)), X_i]
            
            prediction = np.dot(X_i, theta)
            
            theta = theta - (1/m) * learning_rate * (X_i.T.dot((prediction - y_i)))
            cost += calc_cost(theta, X_i, y_i)
        cost_history[it] = cost
    return theta, cost_history

# %%
lr = .1
n_iter = 200

theta = np.random.randn(2, 1)

theta, cost_history = minibatch_gradient_descent(X, y, theta, lr, n_iter)

print_results(theta, cost_history)
# Out:
# Theta0: 3.811
# Theta1: 3.124
# Final Cost (MSE): 979.906

# %%
fig,ax = plt.subplots(figsize=(10,8))

ax.set_ylabel('{J(Theta)}',rotation=0)
ax.set_xlabel('{Iterations}')
theta = np.random.randn(2,1)

ax.plot(range(n_iter), cost_history,'b.')
